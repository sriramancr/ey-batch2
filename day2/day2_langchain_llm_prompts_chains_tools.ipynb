# %%
import os
from langchain_openai import ChatOpenAI

# %%
api_key = "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"

# %%
# llm = ChatOpenAI(api_key=api_key)
llm = ChatOpenAI()

# %%
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x00000212D160D2B0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000212D160DD30> root_client=<openai.OpenAI object at 0x00000212D0B270E0> root_async_client=<openai.AsyncOpenAI object at 0x00000212D160D400> model_kwargs={} openai_api_key=SecretStr('**********')

# %%
# ******************************************
# 1) Simple LLM
# Description: Interfaces for language models
# *******************************************
def run(prompt):
    try:
    
        messages = [ ("system", "You are a helpful assistant good in giving information",),
                    ("human", prompt), ]
        
        response = llm.invoke(messages)
        # content = response
        # print(response.content)
    
    except Exception as e:
        response = "Exception from run()." + "\n" + str(e)
    
    return (response)

# %%
# 0-shot prompt
prompt = "Is time travel really popssible. Give 3 key points"
response = run(prompt)

# %%
print("Full Response")
print(response)

print()
# Contents
print("Contents ...")
print(response.content)
print()

# Token usage
print("Tokens Usage ...")
print(response.response_metadata["token_usage"])
# Out:
# Full Response
# content="As of current scientific understanding, time travel is not possible. Here are three key points to consider:\n\n1. Theoretical Possibilities: While theories such as Einstein's theory of relativity allow for the concept of time dilation, where time can appear to move differently for observers in relative motion, actual time travel to the past or future is still purely theoretical.\n\n2. Paradoxes: The concept of time travel to the past raises complex paradoxes, such as the famous grandfather paradox where one could potentially go back in time and prevent their own existence. Resolving such paradoxes presents significant challenges to the idea of time travel.\n\n3. Technological Limitations: The technology required to manipulate time on a scale large enough for human time travel is far beyond our current capabilities. The energy requirements, potential dangers, and ethical implications of time travel also pose significant hurdles.\n\nIn conclusion, while time travel remains a fascinating topic in science fiction and theoretical physics, at present, it is not considered feasible or practical in the real world." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 204, 'prompt_tokens': 33, 'total_tokens': 237, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DmFxviFJpkBkf5emkiaHO3lVFh4fh', 'finish_reason': 'stop', 'logprobs': None} id='run--3fc9bc21-f996-4b3e-8a78-409391969d80-0' usage_metadata={'input_tokens': 33, 'output_tokens': 204, 'total_tokens': 237, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# Contents ...
# As of current scientific understanding, time travel is not possible. Here are three key points to consider:
#
# 1. Theoretical Possibilities: While theories such as Einstein's theory of relativity allow for the concept of time dilation, where time can appear to move differently for observers in relative motion, actual time travel to the past or future is still purely theoretical.
#
# 2. Paradoxes: The concept of time travel to the past raises complex paradoxes, such as the famous grandfather paradox where one could potentially go back in time and prevent their own existence. Resolving such paradoxes presents significant challenges to the idea of time travel.
#
# 3. Technological Limitations: The technology required to manipulate time on a scale large enough for human time travel is far beyond our current capabilities. The energy requirements, potential dangers, and ethical implications of time travel also pose significant hurdles.
#
# In conclusion, while time travel remains a fascinating topic in science fiction and theoretical physics, at present, it is not considered feasible or practical in the real world.
#
# Tokens Usage ...
# {'completion_tokens': 204, 'prompt_tokens': 33, 'total_tokens': 237, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}

# %%
'''Exercise: 
Create 3 responses for a prompt using different temperature values.
Temp determines the output. 0 -> deterministic 1 -> porbabilitis
'''

# llm = ChatOpenAI(temperature = 0.01,api_key = apikey)

# other values: 0.45, 0.8

# compare the 3 outputs

temperatures = [0.1, 0.5, 0.8]

for t in temperatures:
    llm = ChatOpenAI(api_key = apikey, temperature = t)
    response = run(prompt)
    # process prompt response for the given temperature

# %%
# 1-shot prompt
prompt = '''
Generate a short, enticing product description for a 'WhisFlow' smart air purifier, 
highlighting its quiet operation and intelligent air quality sensing.

Start with the text 'Introducing the WhisperFlow humidifier....'
'''
response = run(prompt)
print(response.content)
# Out:
# Introducing the WhisperFlow smart air purifier - the ultimate solution for clean, fresh air in your home! With its whisper-quiet operation, you'll barely even notice it's there. This advanced device features intelligent air quality sensing technology that automatically adjusts to maintain optimal air quality levels. Say goodbye to allergens and odors, and hello to a healthier living environment with WhisperFlow!

# %% [markdown]
# # --------------------------------------------------------
# # 2) Parameterized templates / Placeholder-based templates
# # --------------------------------------------------------
#
# '''
# Use LangChain PromptTemplate when:
#     Building AI applications
#     Chains/agents
#     Reusable workflows
#     Multi-step pipelines
#     Production systems
#     Multi-agent orchestration
# '''

# %%
# *************************************************
#   2.1) Component: Prompt Templates
#   Build templates to optimize LLM queries / prompts
# *************************************************

# from langchain.prompts import PromptTemplate # old version
from langchain_core.prompts import PromptTemplate # recent

# 1)
# topic = "temples and architecture" # gives the full answer

topic = "trekking and hiking"

try:
    pt = PromptTemplate(input_variables=["topic"], 
                        template="what are the top 5 destinations for people who love {topic}?" )

    # print(pt)
    prompt = pt.format(topic=topic)
    
    # prompt = pt.format()
    # Python f formatting will not identify if 'topic' is missing

    print(prompt)
    response = run(prompt)
    print(response.content)

except Exception as e:
    print("Exception : " + str(e))
# Out:
# what are the top 5 destinations for people who love trekking and hiking?
# There are many amazing trekking and hiking destinations around the world, but here are the top 5 that are often loved by enthusiasts:
#
# 1. Nepal - Home to the famous Everest Base Camp trek and Annapurna Circuit, Nepal offers some of the most breathtaking and challenging trekking routes in the world.
#
# 2. Peru - The Inca Trail to Machu Picchu is a bucket-list hike for many adventurers, but Peru also offers other amazing treks like the Salkantay Trek and Choquequirao.
#
# 3. New Zealand - Known for its stunning landscapes, New Zealand offers a variety of trekking options including the famous Milford Track, Routeburn Track, and Tongariro Alpine Crossing.
#
# 4. Patagonia, Argentina/Chile - The rugged beauty of Patagonia offers some of the most epic trekking experiences in the world, with trails like the W Trek in Torres del Paine National Park and the Dientes de Navarino Circuit.
#
# 5. Switzerland - With its well-maintained hiking trails, picturesque alpine scenery, and charming mountain villages, Switzerland is a favorite destination for hikers. The Haute Route, the Eiger Trail, and the Bernese Oberland are popular trekking routes in Switzerland.
#
# These destinations are beloved by trekkers and hikers for their stunning natural landscapes, diverse terrains, and unique cultural experiences.

# %%
# 2) 2 parameters
temp = "tell me a {p1} fact about {p2}"
pt = PromptTemplate.from_template(temp)

print(pt)
# Out:
# input_variables=['p1', 'p2'] input_types={} partial_variables={} template='tell me a {p1} fact about {p2}'

# %%
prompt = pt.format(p1="medical",p2="carbon")
print(prompt)
print()

response = run(prompt)
print(response.content)
# Out:
# tell me a medical fact about carbon
#
# Carbon is a crucial element in the human body as it is the basic building block of all organic molecules, including carbohydrates, proteins, fats, and nucleic acids.

# %%
# 3) 3 parameters
temp = "write a short note on {p1} and its impact on {p2} and {p3}"
pt = PromptTemplate.from_template(temp)
prompt = pt.format(p1="social media",p2="children",p3="senior citizens")

print(prompt)
response = run(prompt)
print(response.content)
# Out:
# write a short note on social media and its impact on children and senior citizens
# Social media platforms have a significant impact on both children and senior citizens. For children, social media can provide a way to connect with friends, share experiences, and access information. However, it can also expose them to cyberbullying, inappropriate content, and a distorted sense of reality based on others' curated online personas. Parents and guardians need to monitor and guide children's social media use to ensure their safety and well-being.
#
# For senior citizens, social media can offer opportunities for social connection, learning, and entertainment. It can help combat feelings of isolation and loneliness, especially for those who may be physically restricted in their ability to socialize. However, seniors may also be vulnerable to online scams, misinformation, and privacy breaches. Educating seniors on safe online practices and providing support in navigating social media platforms can help them enjoy the benefits while minimizing risks.
#
# Overall, social media can have both positive and negative impacts on children and senior citizens, emphasizing the importance of responsible use, monitoring, and support to ensure a safe and beneficial experience for all users.

# %% [markdown]
# # ====================================================
# # 3) Component: Chains
# # Combine LLMs and Prompt templates to build workflows
# # ====================================================

# %%
# ***********************************************************************************************************
# example 3.1 
# simple chain without any input parameter and output parser
# # A basic single-step chain that takes a user query, formats it using a prompt, and gets an answer from the LLM.
# ***********************************************************************************************************

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# i) Create the LLM
# llm = ChatOpenAI()

# ii) Create the Prompt
qry = ''' 
    A company is planning to conduct a training program on AI to its leaders.
    Suggest a suitable program name in about 5 words.
    '''
prompt = PromptTemplate.from_template(qry)
print(prompt)
# Out:
# input_variables=[] input_types={} partial_variables={} template=' \n    A company is planning to conduct a training program on AI to its leaders.\n    Suggest a suitable program name in about 5 words.\n    '

# %%
# iii) Create the LLM Chain
# new method
# this method is called LCEL (LangChain Expression Language)
# Connect AI components such as prompts, models, data retrievers, and parsers using a simple, chainable syntax with the pipe | operator, enabling smooth data flow from one component to the next.

# It is designed to simplify the creation of complex AI pipelines while keeping code clean, modular, and readable.

chain = prompt | llm

# %%
# iv) Run it
result = chain.invoke({})
print(result.content)
# Out:
# "Leading with AI: A Leadership Training"

# %% [markdown]
# # ***********************************************************************************************************
# # example 3.2
# # simple chain with input parameter and an output parser
# # A basic single-step chain that takes a user query, formats it using a prompt,
# # gets an answer from the LLM, formats the response
# # ***********************************************************************************************************

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# i) Create the LLM
# llm = ChatOpenAI()

# ii) Create the Prompt
prompt = PromptTemplate(input_variables=["topic"], 
                        template="Explain in 3 bullet points the concept of {topic}" )

# %%
topic = "Quantum Computing"

# iii) Create the LLM Chain
chain = prompt | llm | StrOutputParser()

# %%
# iv) Run it
result = chain.invoke({"topic":topic})
print(result)
# Out:
# - Quantum computing utilizes principles of quantum mechanics to perform calculations and solve complex problems more efficiently than traditional computers
# - Quantum computers use quantum bits, or qubits, which can exist in multiple states simultaneously, enabling them to process and store a vast amount of information
# - Quantum computing has the potential to revolutionize fields such as cryptography, artificial intelligence, and drug discovery by solving problems that are currently intractable for classical computers.

# %% [markdown]
# # Assignment 2:
# # Create a chain to take an input from a user on a Tax related topic eg: GST.
# # Create the Prompt Template.
# # Format the output using Parser.
# # Run and display the result

# %% [markdown]
# '''
# Use PromptTemplate when
# -----------------------
#     your prompt is basically one text block.
#     you have a single instruction
#     you do not need roles like system/human
#     your prompt is just one plain string
#     you are building a simple chain quickly
#
# example usage:
#     summarization
#     classification
#     rewriting
#     extraction
#     one-shot Q&A
#
# Use ChatPromptTemplate when
# ---------------------------
#     you want the prompt in chat-message format like system, human, assistant.
#     you are using a chat model
#     you want system instructions
#     you want separate human / AI / system messages
#     you want to include chat history later
#     you want better structure and control
#
# example usage:
#     assistants
#     conversation apps
#     role-based prompting
#     multi-message workflows
#     memory/chat-history use cases
# '''

# %% [markdown]
# # ********************************************
# # example 3.3
# # Example of ChatPromptTemplate with Parser
# # ********************************************

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# %%
# Step 1: Define the prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful customer support assistant."),
    ("human", "Customer issue: {issue}")
])

# Step 2: Initialize LLM
# llm = ChatOpenAI(model="gpt-4o", temperature=0)

# Step 3: Create chain (new style)
chain = prompt | llm | StrOutputParser()

# Step 4: Invoke with input
response = chain.invoke({
    "issue": "My internet connection keeps disconnecting every 10 minutes."
})

# print(response.content)
print(response)
# Out:
# I'm sorry to hear that you're experiencing issues with your internet connection disconnecting every 10 minutes. Here are a few steps you can take to troubleshoot the issue:
#
# 1. Check the physical connections: Make sure that all cables connected to your router and modem are secure and not damaged.
#
# 2. Restart your router and modem: Sometimes, simply restarting your network equipment can help resolve connectivity issues.
#
# 3. Update your router's firmware: Check if there are any firmware updates available for your router and install them if needed.
#
# 4. Reset your router: If the issue persists, you may want to reset your router to its factory settings and reconfigure it.
#
# 5. Check for interference: Nearby electronic devices or appliances can sometimes interfere with your Wi-Fi signal. Try moving your router to a different location to see if that helps.
#
# <source>Information source: Tech support knowledge base</source>
#
# If these steps don't resolve the issue, you may want to contact your internet service provider for further assistance or to schedule a service call.

# %%
# **************************
# example 3.4 : JSON Parser
# **************************
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_openai import ChatOpenAI

# %%
# Step 1: Define parser with expected schema
parser = JsonOutputParser()
format_instructions = parser.get_format_instructions()

# Step 2: Create prompt template
prompt = ChatPromptTemplate.from_template("""
You are an AI assistant that classifies support tickets.

Extract the following fields:
- category
- priority
- suggested_action

{format_instructions}

User Query:
{query}
""")

# Step 3: Initialize LLM
llm = ChatOpenAI(model="gpt-4o", temperature=0)

# Step 4: Create chain
chain = prompt | llm | parser

# Step 5: Invoke
response = chain.invoke({
    "query": "My laptop is overheating and shutting down frequently.",
    "format_instructions": format_instructions
})

print(response)
# Out:
# {'category': 'Hardware Issue', 'priority': 'High', 'suggested_action': 'Check for dust in the cooling vents, ensure the fan is working properly, and consider using a cooling pad. If the issue persists, contact technical support for further assistance.'}

# %%
# extract the individual values of the response

v1 = response['category']
v2 = response['priority']
v3 = response['suggested_action']

# %%
# *****************************
# example 3.5: Sequential Chain
# Sequential chains allow you to connect multiple chains and compose them into pipelines 
# that execute some specific scenario.
# Returns only the final response 
# *******************************

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Step 1: Content
content_prompt = PromptTemplate( 
                input_variables=["title"],
                template="""You are an expert content writer.
                    Given a title, create a professional and high quality content with a suitable heading.
                    The content should not exceed 1000 words. 
                
                    Title: {title}
                
                    Content:""" 
                )

# Step 2: Summary
summary_prompt = PromptTemplate(
            input_variables=["contents"],
            template="""You are an expert editor of text documents.
                    Given the content on a topic, write a crisp 75-word summary. Retain the same heading.

                    Topic Content:
                    {contents}
                
                    Summary:"""
                )

parser = StrOutputParser()

# %%
# runnable chains
content_chain = content_prompt | llm | parser
summary_chain = summary_prompt | llm | parser

# full pipeline
chain = content_chain | (lambda contents: {"contents": contents}) | summary_chain

# %%
response = chain.invoke({"title": "Empowering women for enterpreneurship"})
response

# %%
# Method 2 - using 1 LLM call
# ---------------------------

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser

combined_prompt = ChatPromptTemplate.from_template("""
You are a content writer.

For the given title:
1. Write detailed content.
2. Then write a short summary of that content.

Return the output strictly as JSON with these keys:
- contents
- summary

Title: {title}
""")

parser = JsonOutputParser()

chain = combined_prompt | llm | parser

response = chain.invoke({
    "title": "Social media impact on children"
})

# %%
print(response['contents'])

# %%
print(response['summary'])

# %% [markdown]
# # =========================================================
# # 4) Component: Tools and Agents
# # Agent: Use LLMs to choose a specific activity to perform
# # Tool: Used by agents to perform a specific task
# # ========================================================

# %%
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI

# %%
# Step 1: Create the tools
# -------------------------

# Tool 1
@tool
def convert_degree_to_fahrenheit(celsius: float) -> float:
    """
    Convert temperature from Celsius to Fahrenheit.
    """
    return (celsius * 9/5) + 32


# Tool 2
@tool
def convert_fahrenheit_to_degree(fahrenheit: float) -> float:
    """
    Convert temperature from Fahrenheit to Celsius.
    """
    return (fahrenheit - 32) * 5/9

# %%
# Step 2: Register the Tools
# --------------------------

llm = ChatOpenAI(model="gpt-4o")

# Register the tools
tools = [ convert_degree_to_fahrenheit, convert_fahrenheit_to_degree ]

llm_with_tools = llm.bind_tools(tools)

# %%
# Step 3: Format the Prompts
# --------------------------

user_prompt = "convert 35 degrees C to F"

prompt = f''' You are an intelligent calculation agent who understands the input well and calls the correct tools.
             You have been given the following tools: {tools}

             Read the below user query well. 
             Select the right tool and automatically execute the user query using the tool name and parameters.
             Do not guess the tool name. If you cannot make out, return the response "No Tool Selected".

            User Prompt: {user_prompt}
'''

# %%
# Step 4: Invoke the prompt to determine the correct tool usage
# -------------------------------------------------------------

response = llm_with_tools.invoke(prompt)

# %%
# Step 5: HITL to determine if the tool is the right one
# -------------------------------------------------------

tool_registry = {tool.name: tool for tool in tools }

tool_call = response.tool_calls
print(tool_call)

# %%
# Step 6: Print the tool name with its arguments
# -----------------------------------------------

tool_name = tool_call[0]["name"]
tool_args = tool_call[0]["args"]

print(tool_name,tool_args)

# %%
# Step 7: Invoke the tool call 
# ----------------------------
result = tool_registry[tool_name].invoke(tool_args)

# %%
# Step 8: Print the result
# ------------------------
print(result)

# %%
# **************** NOTE ************************
# LLM decides the use of tools.
# if llm knows the answer, it will answer; else answer goes to the tool
# -----------------------------------------------------------------------------------

# %%
# pip install -U langchain langchain-openai langchain-community wikipedia

# ---------------------------------
# Example 2: Tool usage - Wikipedia
# ----------------------------------

from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from langsmith import Client
from langchain.agents import create_agent

# %%
llm = ChatOpenAI(api_key = api_key)

# %%
# 1) Tool Initialization
wiki = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=1000) )
tools = [wiki]

# %%
# 2) Create the Agent
agent = create_agent(llm=llm, tools=tools,system_prompt="You are a helpful Assistant")

# %%
# 3) User / Content Message

content_msg = "What is climate change"
msg = {"messages":[{"role":"user", "content":content_msg}]}

# %%
# 4) Run the Agent
result = agent.invoke(input=msg)

# %%
# 5) Print the response
print(result)

# %%
# (example 3) : 
# LLM + python functions as Tools
from langchain_openai import ChatOpenAI
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool
from langchain.agents import create_react_agent
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
# pip install duckduckgo-search

# 1) Create the tool
# ------------------
@tool
def extract_entities(text: str) -> dict:
    """Extract named entities and their types from the given input text."""
    entities = []

    tokens = word_tokenize(text)
    tagged = pos_tag(tokens)
    tree = ne_chunk(tagged)

    for subtree in tree:
        if hasattr(subtree, "label"):
            for token, pos in subtree:
                entities.append(f"{subtree.label()}:{token}")

    return {"entities": entities}

search = DuckDuckGoSearchRun()

# Register the tools
tools = [search, extract_entities]

# LLM initialization
llm = ChatOpenAI()

# %%
# 2) User content / Prompt

user_content = ''' Generate a 200-word text document on the topic 'Evolution of Engineering'. 
Include names of Cities and Countries, people, year and other entities wherever possible.
From the generated content, extract the first 15 entities and entity types. Give the result in a JSON format
'''

# %%
# 3) Create the Agent
agent = create_agent(llm=llm, tools=tools,system_prompt="You are an expert in writing and creating documentation on various topics")

# %%
# 4) Invoke the Agent
response = agent.invoke({"messages":[{"role":"user", "content":user_content}]})

# %% [markdown]
# # Database as a Tool
# '''
# Flow:
# 1. User prompt
# 2. LLM selects one logical tool name
# 3. Python function executes matching SQL tool
# 4. LLM generates final analyst-style answer
# '''

# %%
import os
import mysql.connector
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Step 1: Connect to the MySQL Database
# -------------------------------------

host = "localhost"; database="ey"; port=3306; user="root"; pwd="root"

# 1) Get MySQL Connection
# -----------------------
def get_mysql_conn():
    try:
        conn = mysql.connector.connect( host=host, port=port, database=database, user=user, password=pwd)
    except Exception as e:
        conn = str(e)

    return(conn)


conn = get_mysql_conn()
print(conn)

# %%
# 2) List of queries based on the flag
# ------------------------------------

def ExecuteQuery(action, query, values=None):
    ret = {"status": '', "message": "", "record": ""}
    act_msg = ''
    CURSOR = conn.cursor(dictionary=True)

    try:
        if action == "I":
            act_msg = "Inserted"
        elif action == "U":
            act_msg = "Updated"
        elif action == "D":
            act_msg = "Deleted"
        elif action == "S":
            act_msg = "Retrieved"

        if action in ["I", "U", "D"]:
            CURSOR.execute(query, values)
            conn.commit()
            ret["status"] = "SUCCESS"
            ret["message"] = f"{CURSOR.rowcount} Record(s) {act_msg}"
            ret["record"] = ''
        elif action == "S":
            if values is not None:
                CURSOR.execute(query, values)
            else:
                CURSOR.execute(query)

            data = CURSOR.fetchall()
            ret["status"] = "SUCCESS"
            ret["message"] = f"{len(data)} Record(s) {act_msg} "
            ret["record"] = pd.DataFrame(data)

    except Exception as e:
        ret["status"] = "EXCEPTION"
        ret["message"] = str(e)
        ret["record"] = ''
        CURSOR.close()

    finally:
        CURSOR.close()

    return (ret)

# %%
# 3. SQL Tool Definitions
# -----------------------------
def user_access_tool():
    ''' user access tool'''

    query = """
    SELECT * FROM data_security  WHERE failed_logins_24h > 3 AND department = 'Risk';
    """
    return ExecuteQuery(action="S",query=query)

def risk_threat_scoring_tool():
    ''' risk threat scroring tool '''

    query = """
    SELECT department, AVG(risk_score) AS avg_risk FROM data_security GROUP BY department ORDER BY avg_risk DESC;
    """
    return ExecuteQuery(action="S",query=query)

def data_exfiltration_tool():
    ''' data exfiltration tool '''
    
    query = """
    SELECT user_id, device_type, data_sensitivity_level
    FROM data_security
    WHERE data_sensitivity_level > 4;
    """
    return ExecuteQuery(query=query,action="S")

def device_endpoint_compliance_tool():
    ''' device endpoint compliance tool '''
    
    query = """
    SELECT device_type, encryption_in_transit_flag, unmanaged_device_flag
    FROM data_security
    WHERE unmanaged_device_flag = 0;
    """
    return ExecuteQuery(query=query,action="S")

def fallback_sql_tool():
    ''' fallback sql tool '''

    query = """ SELECT * FROM data_security LIMIT 10; """
    return ExecuteQuery(query=query,action="S")

# %%
# 4) LLM
# -------

llm = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
# 5) System Prompt
# ----------------

sys_prompt = """
You are a tool-selection agent for a BFSI data security dataset.

Choose exactly one tool from the following:

1. user_access
Use for:
- failed logins
- suspicious login behavior
- privileged users
- non-business hours access
- authentication issues

2. risk_threat_scoring
Use for:
- risk score
- threat score
- high-risk users
- department-wise risk
- average risk

3. data_exfiltration
Use for:
- DLP violations
- customer financial records
- data sensitivity
- data transfer
- data leakage
- exfiltration

4. device_endpoint_compliance
Use for:
- unmanaged devices
- endpoint compliance
- encryption
- non-compliant devices
- device security

5. fallback_sql
Use for:
- Any other string not matching any of the above

Return only the tool name.
"""

# %%
# 6) Format the Prompt Template
# ------------------------------

select_tool_prompt = ChatPromptTemplate.from_messages([ ("system", sys_prompt), ("human", "{user_prompt}") ])

select_tool_chain = select_tool_prompt | llm | StrOutputParser()

# %%
# 7) Select the appropriate tool based on the prompt
# --------------------------------------------------

# user_prompt = "Show non-compliant endpoints connected to confidential banking resources." 
user_prompt = "dum sum rim jhim"

selected_tool = select_tool_chain.invoke({ "user_prompt": user_prompt})

selected_tool = selected_tool.strip().lower()

valid_tools = [ "user_access", "risk_threat_scoring", "data_exfiltration", "device_endpoint_compliance", "fallback_sql" ]

if selected_tool not in valid_tools:
    selected_tool = "fallback_sql"

# %%
print(selected_tool)
# Out:
# fallback_sql

# %%
# 8) Invoke the right tool based on retrieval
# -------------------------------------------

if selected_tool == "user_access":
    sql_result = user_access_tool()

elif selected_tool == "risk_threat_scoring":
    sql_result = risk_threat_scoring_tool()

elif selected_tool == "data_exfiltration":
    sql_result = data_exfiltration_tool()

elif selected_tool == "device_endpoint_compliance":
    sql_result = device_endpoint_compliance_tool()

else:
    sql_result = fallback_sql_tool()

status = sql_result
if status["status"] == "SUCCESS":
    print(status["record"])

# %% [markdown]
# # *********************************
# # Direct Execution without if..else
# # *********************************

# %%
selected_tool+="_tool"

# Register the tools
tools = [user_access_tool, risk_threat_scoring_tool, data_exfiltration_tool, device_endpoint_compliance_tool,fallback_sql_tool]
tool_registry = {tool.__name__: tool for tool in tools }

# %%
ret = tool_registry.get(selected_tool)()

status = ret['status']
record = ret['record']

if status == "SUCCESS":
    print(record)
# Out:
#   event_id     event_timestamp user_id         department     user_role  \
# 0    E0001 2026-03-30 02:25:00   U1141  Corporate Banking       Analyst
# 1    E0002 2026-03-17 11:00:00   U1024               Risk     Associate
# 2    E0003 2026-03-30 06:09:00   U1136            Finance       Manager
# 3    E0004 2026-03-08 08:27:00   U1251     Retail Banking      Ops Lead
# 4    E0005 2026-03-23 02:12:00   U1293               Risk       Manager
# 5    E0006 2026-03-08 01:04:00   U1112               Risk       Auditor
# 6    E0007 2026-03-07 00:40:00   U1126         Operations     Associate
# 7    E0008 2026-03-02 19:34:00   U1128         Operations      Director
# 8    E0009 2026-03-02 17:47:00   U1177  Corporate Banking  Risk Officer
# 9    E0010 2026-03-21 02:57:00   U1087               Risk      DB Admin
#
#   access_type      resource_name storage_layer transmission_layer  \
# 0        READ  Credit_Risk_Model       At Rest    Public Internet
# 1       LOGIN      KYC_Doc_Store       At Rest        Private API
# 2        READ      KYC_Doc_Store       Archive        Private API
# 3        READ      Audit_Archive        Backup       Internal LAN
# 4      EXPORT    Treasury_Trades       Archive        Private API
# 5    API_CALL    Customer_PII_DB        Backup       Internal LAN
# 6       WRITE  Credit_Risk_Model       Archive        Private API
# 7       LOGIN      Audit_Archive       Archive               SFTP
# 8       LOGIN      Audit_Archive       Archive                VPN
# 9       LOGIN      KYC_Doc_Store        Backup       Internal LAN
#
#         device_type  ... velocity_access_count_1h  genai_anomaly_score  \
# 0   Service Account  ...                        3               0.0510
# 1            Server  ...                        1               0.0250
# 2  Unmanaged Laptop  ...                        7               0.5210
# 3    Managed Laptop  ...                        6               0.4190
# 4    Managed Laptop  ...                        4               0.2480
# 5            Mobile  ...                        3               0.4100
# 6               VDI  ...                       10               0.1190
# 7               VDI  ...                        3               0.4140
# 8            Mobile  ...                        3               0.3010
# 9   Service Account  ...                        1               0.3330
#
#    auth_confidence_score dlp_policy_hits risk_score  step_up_auth_required  \
# 0                 0.9900               1    25.2000                      0
# 1                 0.9900               0    32.3000                      0
# 2                 0.8710               1    56.9000                      1
# 3                 0.8880               0    18.1000                      0
# 4                 0.9420               0    23.3000                      0
# 5                 0.7870               1    56.2000                      0
# 6                 0.9900               0    49.5000                      0
# 7                 0.8460               2    30.0000                      0
# 8                 0.8930               3    51.6000                      1
# 9                 0.7760               0    26.4000                      0
#
#    authentication_result  anomaly_flag  unauthorized_access_flag  \
# 0                Success             0                         0
# 1                Success             0                         0
# 2                Step-Up             1                         0
# 3                Success             0                         0
# 4                Failure             0                         0
# 5                Success             1                         0
# 6                Success             1                         0
# 7                Success             0                         0
# 8                Step-Up             0                         0
# 9                Success             0                         0
#
#    breach_scenario_label
# 0                 Normal
# 1                 Normal
# 2                Monitor
# 3                 Normal
# 4                 Normal
# 5                Monitor
# 6                Monitor
# 7                 Normal
# 8                Monitor
# 9                 Normal
#
# [10 rows x 35 columns]
